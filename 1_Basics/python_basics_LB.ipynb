# %%
import pandas as pd
import numpy as np

# %% [markdown]
# import pandas as pd

# %%
salary = 100000

# %%
base_salary = 100000
bonus_rate = .10

# %%
total_salary = (base_salary) * (1 + bonus_rate)

# %%
total_salary
# Out:
# 110000.00000000001

# %%
company_name = 'DataWiz Inc'

# %%
company_name
# Out:
# 'DataWiz Inc'

# %%
type(company_name)
# Out:
# str

# %%
id(company_name)
# Out:
# 134510967475312

# %%
job_skill = 'SQL'
applicant_skill = 'Python'
years_experience = 3

if job_skill == applicant_skill:
    print('skills match')
elif years_experience <= 5:
    print('enough experience, no SQL')
# elif applicant_skill == 'Pyhton':
    # pass
else:
    print('no skill or experience')
# Out:
# enough experience, no SQL

# %% [markdown]
# ##Lists

# %%
job_skills.append('python')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14133/2898077723.py in <cell line: 0>()
# ----> 1 job_skills.append('python')
#
# NameError: name 'job_skills' is not defined

# %%
job_skills

# %%
job_skills.remove('python')

# %%
job_skills

# %%
job_skills.append('excel')

# %%
job_skills

# %%
job_skills[2]

# %%
job_skills.insert(2, 'tableau')

# %%
job_skills

# %%
job_skills.pop(1)

# %%
# slicing
job_skills[0:2]

# %%
job_skills[:1]

# %%
job_skills[::1]

# %%
job_skills

# %%
job_skills.insert(1, 'python')

# %%
job_skills

# %%
job_skills[::2]

# %%
# unpacking
# assogn each value in an iterable variable in one statement
skill1, skill2, skill3, skill4 = job_skills

# %%
print(skill1)
print(skill3)
print(skill2)

# %% [markdown]
# ##Dictionaries

# %%
job_type_skills = {
'database': 'postgresql', 'language': 'python',
'library': 'pandas'
}

# %%
job_type_skills

# %%
job_type_skills.keys(

)

# %%
job_type_skills.values()

# %%
job_type_skills.pop('library')

# %%
job_type_skills

# %%
job_type_skills.update({'cloud':'goolge cloud'})

# %%
job_type_skills

# %%
job_type_skills['version_control'] = 'git'

# %%
job_type_skills

# %% [markdown]
# ##Sets
# Uniquie values within a container

# %%
skill_list = ['python', 'sql', 'statistics', 'tableau', 'python', 'sql', 'statistics', 'tableau']

# %%
skill_list

# %%
set(skill_list)

# %%
skill_list

# %%
list(set(skill_list))

# %% [markdown]
# ##Tuples
# Defined by parenthesis- Tuples are for fixed data.

# %%
lukes_skill = ('python', 'sql', 'ststistics','tableau')
print(id(lukes_skill))
new_skills = ('excel', 'power bi')

lukes_skill += new_skills

# %%
lukes_skill

# %%
id(lukes_skill)

# %% [markdown]
# ##Range()

# %%
range(5)

# %%
tuple(range(5))

# %%
#start value 2 up to 5
tuple(range(2,5))

# %%
#useful if you need to iterate between a certain range of numbers eg 1 - 100 showing every odd numer.
tuple(range(1, 101, 2))

# %%
tuple(range(1, 51)) #print 1 -50

# %%
job_work_from_home = True
job_health_insurance = False
job_degree = True
job_work_from_home and job_health_insurance and job_degree

# %% [markdown]
# ##Logic Operators

# %%
# anytime either is not True, it's going to be false

# %%
job_work_from_home = True
job_health_insurance = False
job_degree = True
job_work_from_home or job_health_insurance and job_degree

# %%
if job_work_from_home or job_health_insurance or not job_degree:
    print("meets conditions")

# %% [markdown]
# ##Membership Operators
# Checks if one object is inside another object

# %%
"data" in "Databse" #case sensitive

# %% [markdown]
# ##Identity Operators

# %%
salary_kelly = 100_000
salary_luke = 100_000

salary_kelly is salary_luke

# %%
id(salary_kelly) == id(salary_luke)

# %%
 id(salary_luke)

# %% [markdown]
# ##Loops
# For Loops
# While Loops

# %%
numbers = [0, 1, 2, 3, 4, 5]

for number in numbers:
    print (number) # number variable. numbers iterable

# %%
years_experience = {
    'Luke': 3,
    'Kelly': 6,
    'Ken': 4,
    'Alex': 3,
    'Mary': 7
}

# %%
for person in years_experience:
    print(person)

# %%
for value in years_experience.values():
    print(value)

# %%
for key, value in years_experience.items():
    print(key, value)

# %%
for key, value in years_experience.items():
    if value > 5:
        print(key, 'has', value, 'years experience')

# %%
# while True:
    # print(hello dave) will run infiniitely!

# %%
count = 1
while count  < 5:
    print ('hello dave')
    count += 1

# %%
# return the first person who meets the criteria of 5 years experience

# %%
# from ast import Index
years = 0
index = 0

years_list = list(years_experience.items()
                  )
while years < 5:
    key, years = years_list[index]
    if years >= 5:
        print(key, 'has', years, 'years of experience')
    index += 1

# %%
years_list[3]

# %% [markdown]
# ##List Comprehension
# [x for x in range(10)

# %%
job_list = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Business Intelligence Analyst', 'Data Engineer', 'AI Engineer', 'Quantitative Analyst', 'Statistician', 'Research Scientist', 'Analytics Consultant', 'Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Business Intelligence Analyst', 'Data Engineer', 'AI Engineer', 'Quantitative Analyst', 'Statistician', 'Research Scientist', 'Analytics Consultant', 'Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Business Intelligence Analyst', 'Data Engineer', 'AI Engineer', 'Quantitative Analyst', 'Statistician', 'Research Scientist', 'Analytics Consultant', 'Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Business Intelligence Analyst', 'Data Engineer', 'AI Engineer', 'Quantitative Analyst', 'Statistician', 'Research Scientist', 'Analytics Consultant', 'Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Business Intelligence Analyst', 'Data Engineer', 'AI Engineer', 'Quantitative Analyst', 'Statistician', 'Research Scientist', 'Analytics Consultant', 'Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Business Intelligence Analyst', 'Data Engineer', 'AI Engineer', 'Quantitative Analyst', 'Statistician', 'Research Scientist', 'Analytics Consultant', 'Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Business Intelligence Analyst', 'Data Engineer', 'AI Engineer', 'Quantitative Analyst', 'Statistician', 'Research Scientist', 'Analytics Consultant', 'Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Business Intelligence Analyst', 'Data Engineer', 'AI Engineer', 'Quantitative Analyst', 'Statistician', 'Research Scientist', 'Analytics Consultant', 'Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Business Intelligence Analyst', 'Data Engineer', 'AI Engineer', 'Quantitative Analyst', 'Statistician', 'Research Scientist', 'Analytics Consultant']

# %%
# numbers = [x2 for x in range(100)]
# numbers

# %%
# numbers = [x*2 for x in range(100)]
# numbers

# %%
# numbers = [float(x) for x in range(100)]
# numbers

# %%
numbers = [x for x in 'PYTHON']
numbers

# %%
analyst_list = [job for job in job_list if "Data Analyst" in job]

# %%
len(analyst_list)

# %%
print ("Original list is:", len(job_list), "jobs")
print ("New list is:", len(analyst_list), "jobs")

# %%
analyst_list

# %% [markdown]
# ##User Defined Functions

# %%
base_salary

# %%
bonus_rate

# %%
total_salary = base_salary * (1 + bonus_rate)

# %%
total_salary

# %%
# Calculate total_salary of base_salary * (1 + bonus_rate)

def calculate_salary(base, bonus_rate):

    total_salary = base_salary * (1 + bonus_rate)

    return total_salary

# %%
calculate_salary(base_salary, bonus_rate)

# %%
def calculate_salary(base, bonus_rate=.1):

    total_salary = base_salary * (1 + bonus_rate)

    return total_salary

# %%
 salary_1 = 100000
 rate_1 = 0.5

 calculate_salary(2000)

# %% [markdown]
# ##Lambda Functions
# lambda x, y: x + y

# %%
mul_two = lambda x: x*2

# %%
mul_two(3)

# %% [markdown]
# ##Modules

# %%
import my_module

# %%
my_module.skill_list

# %%
my_module.skill("Python")

# %% [markdown]
# ##Statistics

# %%
import statistics
statistics.mean([98000, 250000, 650000])

# %%
salary_list = [98000, 250000, 650000]

# %%
from statistics import mean, mode, median

# %%
print(mean(salary_list))
print(mode(salary_list))
print(median(salary_list))

# %% [markdown]
# ##Data Cleanup

# %%
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2023-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python', 'TensorFlow', 'Deep Learning']", 'job_date': '2023-05-15'},
    {'job_title': 'Data Analyst', 'job_skills': "['SQL', 'R', 'Tableau']", 'job_date': '2023-05-10'},
    {'job_title': 'Business Intelligence Developer', 'job_skills': "['SQL', 'PowerBI', 'Data Warehousing']", 'job_date': '2023-05-08'},
    {'job_title': 'Data Engineer', 'job_skills': "['Python', 'Spark', 'Hadoop']", 'job_date': '2023-05-18'},
    {'job_title': 'AI Specialist', 'job_skills': "['Python', 'PyTorch', 'AI Ethics']", 'job_date': '2023-05-20'}
]

# %%
# Start with datetime

from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2026, 3, 20, 9, 26, 9, 659702)

# %%
data_science_jobs[0]['job_date']
# Out:
# '2023-05-12'

# %%
type(data_science_jobs[0]['job_date'])
# Out:
# str

# %%
# it is a string. we need it as date time

test_date = data_science_jobs[0]['job_date']

# %%
print(datetime.strptime(test_date, '%Y-%m-%d'))
# Out:
# 2023-05-12 00:00:00

# %%
for job in data_science_jobs:
    job['job_date'] = datetime.strptime(job['job_date'], '%Y-%m-%d')

# %%
data_science_jobs
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': "['Python', 'SQL', 'Machine Learning']",
#   'job_date': datetime.datetime(2023, 5, 12, 0, 0)},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': "['Python', 'TensorFlow', 'Deep Learning']",
#   'job_date': datetime.datetime(2023, 5, 15, 0, 0)},
#  {'job_title': 'Data Analyst',
#   'job_skills': "['SQL', 'R', 'Tableau']",
#   'job_date': datetime.datetime(2023, 5, 10, 0, 0)},
#  {'job_title': 'Business Intelligence Developer',
#   'job_skills': "['SQL', 'PowerBI', 'Data Warehousing']",
#   'job_date': datetime.datetime(2023, 5, 8, 0, 0)},
#  {'job_title': 'Data Engineer',
#   'job_skills': "['Python', 'Spark', 'Hadoop']",
#   'job_date': datetime.datetime(2023, 5, 18, 0, 0)},
#  {'job_title': 'AI Specialist',
#   'job_skills': "['Python', 'PyTorch', 'AI Ethics']",
#   'job_date': datetime.datetime(2023, 5, 20, 0, 0)}]

# %%
import ast

for job in data_science_jobs:
    job['job_date'] = datetime.strptime(job['job_date'], '%Y-%m-%d')
    job['job_skills'] = ast.literal_eval(job['job_skills'])

# %%
data_science_jobs
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': ['Python', 'SQL', 'Machine Learning'],
#   'job_date': datetime.datetime(2023, 5, 12, 0, 0)},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'TensorFlow', 'Deep Learning'],
#   'job_date': datetime.datetime(2023, 5, 15, 0, 0)},
#  {'job_title': 'Data Analyst',
#   'job_skills': ['SQL', 'R', 'Tableau'],
#   'job_date': datetime.datetime(2023, 5, 10, 0, 0)},
#  {'job_title': 'Business Intelligence Developer',
#   'job_skills': ['SQL', 'PowerBI', 'Data Warehousing'],
#   'job_date': datetime.datetime(2023, 5, 8, 0, 0)},
#  {'job_title': 'Data Engineer',
#   'job_skills': ['Python', 'Spark', 'Hadoop'],
#   'job_date': datetime.datetime(2023, 5, 18, 0, 0)},
#  {'job_title': 'AI Specialist',
#   'job_skills': ['Python', 'PyTorch', 'AI Ethics'],
#   'job_date': datetime.datetime(2023, 5, 20, 0, 0)}]

# %%
# !pip install pandas

# %% [markdown]
# #NumPy

# %%
import random

# %%
random.randint(50000, 100000)
# Out:
# 58029

# %%
salary_list = [random.randint(50000, 100000) for _ in range(1_000_000)]

# %%
# %%timeit

statistics.mean(salary_list)
# Out:
# 268 ms ± 10.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numpy as np

# %%
# %%timeit
np.mean(salary_list)
# Out:
# 64.7 ms ± 6.13 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
my_array = np.array([1,2,3,4])

# %%
my_array.mean()
# Out:
# np.float64(2.5)

# %%
job_titles = np.array(['Data Analyst', 'Data Scientist', 'Data Engineer', 'ML Engineer', 'AI Engineer'])

base_salaries = np.array([60000, 80000, 75000, 90000, np.nan])

bonus_rates = np.array([.05, .1, .08, .12, np.nan])

# %%
total_salaries = base_salaries * (1 + bonus_rates)

# %%
np.nanmean(total_salaries)
# Out:
# np.float64(83200.0)

# %% [markdown]
# #Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df['total_bedrooms'].median()
# Out:
# 437.0

# %%
df.total_bedrooms[5]
# Out:
# np.float64(213.0)
